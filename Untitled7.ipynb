# %% [markdown]
# <a href="https://colab.research.google.com/github/RajeeshkumarP/Rajeesh/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## String slicing in python
text = "Pythonprogramming"
print(text[0:6])
print(text[0:4])
print(text[1:3])
print(text[3:13])
print(text[0:13])
# Out:
# Python
# Pyth
# yt
# honprogram
# Pythonprogram
